# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithra64/ML-data-cleaning/blob/main/ML_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print("load the dataset")
# Out:
# load the dataset

# %%
df=pd.read_csv('/content/life_expectancy_data.csv')

# %% [markdown]
# **First 5 records**

# %%
print(df.head())
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# **Last 5 records**

# %%
print(df.tail())
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
print(df.shape)
# Out:
# (2938, 22)

# %% [markdown]
# **Description about dataset**

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# **Finding missing values**

# %%
print(df.isnull().sum())
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# **Finding missing values percentage**

# %%
print(df.isnull().sum()/df.shape[0]+100)
# Out:
# Country                            100.000000
# Year                               100.000000
# Status                             100.000000
# Life expectancy                    100.003404
# Adult Mortality                    100.003404
# infant deaths                      100.000000
# Alcohol                            100.066031
# percentage expenditure             100.000000
# Hepatitis B                        100.188223
# Measles                            100.000000
#  BMI                               100.011572
# under-five deaths                  100.000000
# Polio                              100.006467
# Total expenditure                  100.076923
# Diphtheria                         100.006467
#  HIV/AIDS                          100.000000
# GDP                                100.152485
# Population                         100.221920
#  thinness  1-19 years              100.011572
#  thinness 5-9 years                100.011572
# ...

# %% [markdown]
# **Finding duplicate data ratio**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **Finding garbage value in columns**

# %%
for i in df.select_dtypes(include=['object']).columns:
  print(df[i].value_counts())
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %% [markdown]
# **Performing EDA activities**

# %% [markdown]
# Display descriptive statistics of datset

# %%
print(df.describe().T)
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %% [markdown]
# Display descriptive statistics of object columns

# %%
print(df.describe(include="object"))
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %% [markdown]
# **Visualization of EDA**

# %%
for i in df.select_dtypes(include=['number']).columns:
  sns.histplot(data=df,x=i)
  plt.show()

# %% [markdown]
# **Identify outliers in columns using boxplot**

# %%
for i in df.select_dtypes(include=['number']).columns:
  sns.boxplot(data=df,x=i)
  plt.show()

# %% [markdown]
# **Working with missing values**
#
# **Handling numerical missing values**

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
for i in [" BMI ","Polio","Income composition of resources"]:
  df[i].fillna(df[i].median(),inplace=True)

# %% [markdown]
# **After handling missing values**

# %%
print(df.isnull().sum())
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                0
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources      0
# Schooling                          163
# dtype: int64

# %% [markdown]
# **Handling missing value using Knn imputer**

# %%
from sklearn.impute import KNNImputer

# %%
impute=KNNImputer()

# %%
for i in df.select_dtypes(include=['number']).columns:
  df[i]=impute.fit_transform(df[[i]])

# %% [markdown]
# After imputation

# %%
print(df.isnull().sum())
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# **Handling duplicate values**

# %%
print(df.drop_duplicates())
# Out:
#           Country    Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015.0  Developing              65.0            263.0
# 1     Afghanistan  2014.0  Developing              59.9            271.0
# 2     Afghanistan  2013.0  Developing              59.9            268.0
# 3     Afghanistan  2012.0  Developing              59.5            272.0
# 4     Afghanistan  2011.0  Developing              59.2            275.0
# ...           ...     ...         ...               ...              ...
# 2933     Zimbabwe  2004.0  Developing              44.3            723.0
# 2934     Zimbabwe  2003.0  Developing              44.5            715.0
# 2935     Zimbabwe  2002.0  Developing              44.8             73.0
# 2936     Zimbabwe  2001.0  Developing              45.3            686.0
# 2937     Zimbabwe  2000.0  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...
